# %% [markdown]
# ## Libraries

# %%
import pandas as pd 
import numpy as np

# %%
df= pd.read_csv('oceania_covid.csv')
df.head(10)
# Out:
#        Country/Other  Total Cases  Total Deaths  Total Recovered  \
# 0          Australia      3293565          5311        3030616.0
# 1               Fiji        63999           834          62008.0
# 2   French Polynesia        67651           641              NaN
# 3           Kiribati         2953            11           2241.0
# 4      New Caledonia        55502           301          47969.0
# 5        New Zealand       166098            56          19263.0
# 6              Palau         3823             6           3313.0
# 7   Papua New Guinea        41335           638          39714.0
# 8    Solomon Islands         7258           106           1761.0
# 9  Wallis and Futuna          454             7            438.0
#
#    Active Cases  Tot Cases/ 1M pop  Deaths/ 1M pop  Total Tests  \
# 0      257638.0             126715             204   63752087.0
# 1        1157.0              70542             919     497559.0
# ...

# %% [markdown]
# ## Data Source

# %% [markdown]
# #### https://www.kaggle.com/anandhuh/covid-in-oceania-latest-data

# %% [markdown]
# ## Description of the data base

# %% [markdown]
# ### This data base shows the behaviour of covid-19 on Oceania

# %%
df.columns
# Out:
# Index(['Country/Other', 'Total Cases', 'Total Deaths', 'Total Recovered',
#        'Active Cases', 'Tot Cases/ 1M pop', 'Deaths/ 1M pop', 'Total Tests',
#        'Tests/ 1M pop', 'Population'],
#       dtype='object')

# %% [markdown]
# ###### En este caso me enfocaré en las variables de Total cases, Total deaths,Total recovered, Country and Total Tests.

# %%
df.drop(['Tot Cases/ 1M pop','Deaths/ 1M pop','Active Cases','Tests/ 1M pop','Population',],
        axis= 1,
        inplace= True)
df.columns
# Out:
# Index(['Country/Other', 'Total Cases', 'Total Deaths', 'Total Recovered',
#        'Total Tests'],
#       dtype='object')

# %%
df.rename(columns = { 'Country/Other':'Country',},
          inplace= True
         )
df.head()
# Out:
#             Country  Total Cases  Total Deaths  Total Recovered  Total Tests
# 0         Australia      3293565          5311        3030616.0   63752087.0
# 1              Fiji        63999           834          62008.0     497559.0
# 2  French Polynesia        67651           641              NaN          NaN
# 3          Kiribati         2953            11           2241.0          NaN
# 4     New Caledonia        55502           301          47969.0      98964.0

# %% [markdown]
# ## Variable Description

# %% [markdown]
# #### Country-  It's a categorical variable that shows the names of the countries
# #### Total Cases- It's a numerical variable that shows the total of cases on Oceania
# #### Total deaths - It's a numerical variable that shows the total of deaths on Oceania
# #### Total recovered - It's a numerical variable that shows the total of pacients who recovered from covid-19
# #### Total Tests - It's a numerical variable that shows the total number of tests taken

# %% [markdown]
# ## Questions

# %% [markdown]
# #### 1. What is the country with the highest number of cases on the continent of Oceania?

# %%
myPivot = pd.pivot_table(df,
                         index = ['Country'],
                         values= ['Total Cases'],
                        )
myPivot
# Out:
#                    Total Cases
# Country
# Australia              3293565
# Fiji                     63999
# French Polynesia         67651
# Kiribati                  2953
# New Caledonia            55502
# New Zealand             166098
# Palau                     3823
# Papua New Guinea         41335
# Solomon Islands           7258
# Wallis and Futuna          454

# %%
import matplotlib.pyplot as plt

# %%
my_plot = df.plot("Country", "Total Cases", kind="bar")
plt.show()

# %% [markdown]
# #### In conclusion we can say that Australia far exceeds other countries in terms of the number of covid-19 cases

# %% [markdown]
# #### 2. Wich is the country with the fewest deaths on the continent of Oceania?

# %%
myPivot = pd.pivot_table(df,
                         index = ['Country'],
                         values= ['Total Deaths'],
                         aggfunc=['sum'],
                        )
myPivot
# Out:
#                            sum
#                   Total Deaths
# Country
# Australia                 5311
# Fiji                       834
# French Polynesia           641
# Kiribati                    11
# New Caledonia              301
# New Zealand                 56
# Palau                        6
# Papua New Guinea           638
# Solomon Islands            106
# Wallis and Futuna            7

# %%
my_plot = df.plot("Country", "Total Deaths", kind="barh")
plt.show()

# %% [markdown]
# #### En conclusión podemos decir que Palau es el país que cuenta con la menor cantidad de muertes por covid-19.

# %% [markdown]
# #### 3. Cual es el país que cuenta con mayor cantidad de pacientes recuperados de covid-19?

# %%
myPivot = pd.pivot_table(df,
                         index = ['Country'],
                         values= ['Total Recovered'],
                         aggfunc=['sum'],
                        )
myPivot
# Out:
#                               sum
#                   Total Recovered
# Country
# Australia               3030616.0
# Fiji                      62008.0
# French Polynesia              0.0
# Kiribati                   2241.0
# New Caledonia             47969.0
# New Zealand               19263.0
# Palau                      3313.0
# Papua New Guinea          39714.0
# Solomon Islands            1761.0
# Wallis and Futuna           438.0

# %%
my_plot = df.plot("Country", "Total Recovered", kind="bar")
plt.show()

# %% [markdown]
# #### En conclusión podemos decir que Australia es el país que cuenta con más pacientes recuperados de Covid-19

# %% [markdown]
# #### 4.Cual es la distribución y la tendencia del total de muertes por covid-19 en oceanía?

# %%
myPivot = pd.pivot_table(df,
                         index = ['Country'],
                         values= ['Total Deaths'],  
                         aggfunc=['sum'],
                        )
myPivot
# Out:
#                            sum
#                   Total Deaths
# Country
# Australia                 5311
# Fiji                       834
# French Polynesia           641
# Kiribati                    11
# New Caledonia              301
# New Zealand                 56
# Palau                        6
# Papua New Guinea           638
# Solomon Islands            106
# Wallis and Futuna            7

# %%
my_plot = df.plot("Country", "Total Deaths", kind="box",figsize=(20, 10))
plt.show()
